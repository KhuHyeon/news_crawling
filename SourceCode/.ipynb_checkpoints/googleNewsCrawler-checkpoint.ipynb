# %%
from bs4 import BeautifulSoup
from news import News
from newsMail import *
import requests, urllib
import pandas as pd
import matplotlib.pyplot as plt
import os

base_url = "https://news.google.com"

# %%
# 구글 검색시스템을 이용하여 키워드와 관련있는 기사 크롤링
def google_news_clipping(keyword_input, limit=10):
    keyword = urllib.parse.quote(keyword_input)
    url = base_url + "/search?q=" + keyword + "&hl=ko&gl=KR&ceid=KR%3Ako"

    resp = requests.get(url)
    html_src = resp.text
    soup = BeautifulSoup(html_src, 'lxml')

    news_items = soup.select('div[class="xrnccd"]')

    links = []
    titles = []
    contents = []
    agencies = []
    reporting_dates = []
    reporting_times = []

    for item in news_items[:limit]:
        link = item.find('a', attrs={'class': 'VDXfz'}).get('href')
        news_link = base_url + link[1:]
        links.append(news_link)

        news_title = item.find('a', attrs={'class': 'DY5T1d'}).getText()
        titles.append(news_title)

        news_content = item.find('span', attrs={'class': 'xBbh9'}).text
        contents.append(news_content)

        news_agency = item.find('a', attrs={'class': 'wEwyrc AVN2gc uQIVzc Sksgp'}).text
        agencies.append(news_agency)

        news_reporting = item.find('time', attrs={'class': 'WW6dff uQIVzc Sksgp'})
        if news_reporting == None:
            reporting_dates.append("None")
            reporting_times.append("None")
        else:
            news_reporting_datetime = news_reporting.get('datetime').split('T')
            news_reporting_date = news_reporting_datetime[0]
            news_reporting_time = news_reporting_datetime[1][:-1]
            reporting_dates.append(news_reporting_date)
            reporting_times.append(news_reporting_time)

    result = {'link': links, 'title': titles, 'contents': contents, 'agency': agencies, 'date': reporting_dates,\
              'time': reporting_times}
    return result

# %%
# 뉴스 객체 생성
def create_google_news(keyword_input):
    limit = int(input("검색할 뉴스 개수를 입력하세요 : "))
    # 뉴스 데이터 딕셔너리
    news_dict = google_news_clipping(keyword_input, limit)
    # 뉴스 객체 저장 리스트
    news_items = []
    # 뉴스 객체 생성
    for i in range(len(news_dict['title'])):
        news_item = News(news_dict['title'][i], news_dict['link'][i], news_dict['contents'][i], news_dict['agency'][i], news_dict['date'][i], news_dict['time'][i])
        news_items.append(news_item)
    # 크롤링한 기사 출력
    for news_item in news_items:
        news_item.print()
    return news_items

# %%
# 날짜 별 뉴스 수 시각화
def googleNewsTrend(news_items, keyword_input):
    # 날짜별 뉴스 업로드 수 딕셔너리
    date_dict = {}
    for news_item in news_items:
        # 뉴스 기사 업로드 날짜
        date = news_item.date
        # 날짜를 알 수 없는 뉴스는 패스
        if date == "None":
            continue
        if date in date_dict:
            date_dict[date][0] += 1
        else:
            date_dict[date] = [1]

    # 날짜 순으로 정렬한 딕셔너리 만들기
    s_date_dict = {}
    for key in sorted(date_dict):
        s_date_dict[key] = date_dict[key]

    # matplotlib 한글폰트 오류 해결
    from matplotlib import font_manager, rc
    cwd = os.getcwd()
    font_path = os.path.join(cwd, "data", "malgun.ttf")
    font_name = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font_name)

    # 행은 딕셔너리의 key(날짜)로 지정
    # 열은 'count'로 지정 후 내용은 딕셔너리의 value(기사 작성된 수)로 채우기
    data = pd.DataFrame(s_date_dict.values(), index=s_date_dict.keys(), columns=[keyword_input+"'s news count"])
    # 데이터 출력
    #print(data, "\n")

    # 그래프 그리기
    data.plot()

    # 데이터 저장
    cwd = os.getcwd()
    data.to_csv(f"./output/GoogleNews_{keyword_input}.csv")
    
    # 그래프 저장
    output_filepath = f"./output/google_news_graph_{keyword_input}.png"
    plt.savefig(output_filepath, dpi=300)
    plt.show()

# %%
def sendGoolgeNewsByGmail(news_items):
    news_num = input("몇개의 뉴스를 메일로 받고싶으신가요? : ")
    news_num = int(news_num)
    sendNewsByGmail(news_items[:news_num], "구글 뉴스 크롤링")

# %%
if __name__ == "__main__":
    keyword_input = input("검색어를 입력하세요 : ")
    print() # 줄바꿈
    news_items = create_google_news(keyword_input) # 뉴스객체 리스트 생성
# Out:
# 검색어를 입력하세요 : 인공지능
#
# 검색할 뉴스 개수를 입력하세요 : 20
# 제목: "AI 적극 도입으로 지능형 회계서비스시장 선점해야"
# 링크: https://news.google.com/articles/CAIiEJ3ZZSu_L21DTXx6ZbMJNE4qGQgEKhAIACoHCAownY6XCzDwta4DMKqDywY?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 인공지능 시스템은 회계사의 일자리를 대체하는 것이 아니라 회계사의 업무를 효율화시키는 방향으로 발전할 것이라는 분석이 나왔다. 이에 따라 회계사들은 인공 ...
# 언론사: 한국세정신문사
# 날짜&시간: 2020-06-12 06:10:51
# =====================================================
# 제목: 마이크로소프트, 언론인들을 인공지능으로 대체...미래 거대한 물결
# 링크: https://news.google.com/articles/CBMiPmh0dHA6Ly93d3cuZnV0dXJldGltZXMuY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEzODEw0gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: [퓨처타임즈=송호창 기자] 코로나로 광고전멸이 지속되면서 영국의 가디언지 등이 독자들에게 광고나 구독을 구걸하고 있다. MSN에서 수많은 뉴스를 생산하며 ...
# 언론사: 퓨처타임즈
# 날짜&시간: 2020-06-12 02:31:13
# =====================================================
# 제목: "AI학회는 인재 등용문 역할할 것"...유창동 한국인공지능학회장
# 링크: https://news.google.com/articles/CBMiOWh0dHA6Ly93d3cuYWl0aW1lcy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTM4MdIBAA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: "인공지능(AI)은 하나의 분야에서 완성할 수 있는 기술이 아닙니다. 다양한 분야에서 해야 합니다. 한국인공지능학회는 다양한 분야에서 인재와 기술을 교류할 수 있는 ...
# 언론사: AI타임스
# 날짜&시간: 2020-06-12 06:40:32
# =====================================================
# 제목: [IT트렌드 속성 가이드북] 우리나라도 AI 강국이 될 수 있을까?
# 링크: https://news.google.com/articles/CBMiL2h0dHBzOi8vd3d3Lm1vYmlpbnNpZGUuY28ua3IvMjAyMC8wNS8yMS9wZW4tYWkv0gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용
hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 안무가 신창호 교수 무용수 움직임을 찍어 입력 AI 스스로 학습, 동작 만들어인공지능(AI) 기술을 활용한 현대무용 '비욘드 블랙'을 선보이는 신창호 안무가는 “기술에 ...
# 언론사: 한국일보
# 날짜&시간: 2020-06-11 19:30:00
# =====================================================
# 제목: 증권통, 인공지능 주가예측 서비스 '스케치' 베타버전 출시
# 링크: https://news.google.com/articles/CBMiMmh0dHBzOi8vd3d3Lm5ld3N0b21hdG8uY29tL1JlYWROZXdzLmFzcHg_bm89OTc3ODU10gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 모바일 증권 플랫폼 '증권통'이 인공지능 주가예측 서비스 '스케치(Stock Catch)' 베타 ...
# 언론사: 뉴스토마토
# 날짜&시간: 2020-06-12 08:21:00
# =====================================================
# 제목: 인공지능 시대가 오고 있다 : 오피니언·칼럼
# 링크: https://news.google.com/articles/CBMiK2h0dHBzOi8vd3d3LmNocmlzdGlhbmRhaWx5LmNvLmtyL25ld3MvOTEzMTbSAQA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 신본주의 가치관이 지배하던 시기에 인간은 나약한 존재에 불과했다. 인간은 거대한 질서 내지는 신의 섭리와 자연의 질서에 두 손을 놓고만 있어야 하는 존재였다.
# 언론사: 기독일보(한국)
# 날짜&시간: 2020-06-12 06:35:38
# =====================================================
# 제목: [쌀산업 좌표를 찍다 <3>RPC 인공지능을 탑재하다] 생산 계획부터 이력관리까지 스마트하게…인공지능 'u-RPC' 뜬다
# 링크: https://news.google.com/articles/CBMiO2h0dHA6Ly93d3cuYWdyaW5ldC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTc3NTY20gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: [한국농어민신문 이병성 기자]. △ 벼 생산단계에서부터 소비자에게 쌀로 판매하는 모든 과정에 걸쳐 디지털화한 u-RPC가 쌀산업의 체질 개선과 쌀 산지유통 혁신을 ...
# 언론사: 한국농어민신문
# 날짜&시간: 2020-06-12 06:22:57
# =====================================================
# 제목: 인공지능(AI) 디자인 족집게 선생님
# 링크: https://news.google.com/articles/CBMiPWh0dHA6Ly93d3cuYXN0cm9ub21lci5yb2Nrcy9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89ODg5MzLSAQA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 앱 디자인을 도와주는 '인공지능 선생님'이 개발됐습니다. 이 시스템의 도움을 받으면 디자인 비전공자도 쉽고 빠르게 '사용자에게 꼭 맞는' 앱 디자인을 만들어낼 수 ...
# 언론사: 이웃집과학자
# 날짜&시간: 2020-05-13 07:00:00
# =====================================================
# 제목: 부산교육청 AI수학 교과서 개발…내년 진로 선택 과목 개설
# 링크: https://news.google._SAQA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 부산시교육청은 인공지능(AI) 기술에 기반한 지능정보 시대를 맞아 정보·수학 융합 교육 활성화를 위해 '인공지능 수학' 교과와 교과서를 전국 최초로 개발한다고 11일 ...
# 언론사: Science Times
# 날짜&시간: 2020-06-11 22:08:00
# =====================================================
# 제목: '인공지능 돌봄'이 어르신 안전·정서 지킨다
# 링크: https://news.google.com/articles/CBMiOWh0dHA6Ly93d3cuaGFuaS5jby5rci9hcnRpL3NjaWVuY2UvdGVjaG5vbG9neS85NDgzMTEuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: AI 스피커에 어르신 돌봄 기능 구현“아리아 살려줘” 외치면 119에 연락스피커와 감성대화로 외로움도 덜어기억력 향상 프로그램은 치매 예방도.
# 언론사: 한겨레
# 날짜&시간: 2020-06-07 19:59:59
# =====================================================
# 제목: 오존예보 정확도, 인공지능(AI) 예측기술로 높인다
# 링크: https://news.google.com/articles/CBMiP2h0dHA6Ly93d3cuZW5lcmd5ZGFpbHkuY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEwODQwNdIBAA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: [에너지데일리 최일관 기자] 환경부 소속 국립환경과학원(원장 장윤석)은 미세먼지 계절관리기간(12~3월) 예보제 운영 결과를 점검하고, 오는 5월21일부터 오존 ...
# 언론사: 에너지데일리
# 날짜&시간: 2020-05-20 07:00:00
# =====================================================
# 제목: AI 데이터 관리 '올인원'으로
# 링크: https://news.google.com/articles/CBMiO2h0dHA6Ly93d3cuZW5nam91cm5hbC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NzUz0gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: [공학저널 이상오 기자] 이제 AI 데이터 수집부터 분석, 가공까지 한 번에 처리가 가능해진다. 다양한 산업분야에 최적화된 AI 데이터 올인원 플랫폼 서비스가 등장한 ...
# 언론사: 공학저널
# 날짜&시간: 2020-05-22 07:00:00
# =====================================================
# 제목: ACROFAN
# 링크: https://news.google.com/articles/CBMiL2h0dHBzOi8va3IuYWNyb2Zhbi5jb20vZGV0YWlsLnBocD9udW1iZXI9MTk0NDQw0gEA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 인공지능(AI)이 정부가 주도하는 '한국판 뉴딜' 핵심 산업으로 떠오른 가운데, 국내 대표 인공지능 데이터 플랫폼 기업 슈퍼브에이아이가 데이터 라벨링 효율을 최대 ...
# 언론사: ACROFAN South Korea
# 날짜&시간: 2020-06-12 02:56:00
# =====================================================
# 제목: 인공 지능이 그린 사람 얼굴
# 링크: https://news.google.com/articles/CBMiLmh0dHA6Ly93d3cuZG9uZ2FzY2llbmNlLmNvbS9uZXdzLnBocD9pZHg9MzcyNzLSAQA?hl=ko&gl=KR&ceid=KR%3Ako
# 내용: 팝뉴스 제공사람이 얼굴 스케치만 대충 그려도 인공 지능 장치가 정교하고 사실적인 얼굴을 그려낸다.위 사진은 중국 과학 아카데미와 홍콩 대학교의 연구팀이 최근 ...
# 언론사: 동아사이언스
# 날짜&시간: 2020-06-08 14:00:00
# =====================================================

# %%
googleNewsTrend(news_items, keyword_input) # 뉴스 업로드 횟수 시각화

# %%
sendGoolgeNewsByGmail(news_items) # 크롤링한 뉴스 객체 메일로 보내기
# Out:
# 몇개의 뉴스를 메일로 받고싶으신가요? : 10
# 받을 사람의 이메일을 입력해주세요 : dlgustjd1687@naver.com
# dlgustjd1687@naver.com님에게 이메일을 발송하였습니다.
